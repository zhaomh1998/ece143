# %% [markdown]
# # Load household characteristics dataset from
# `http://www.inec.go.cr/ingresos-y-gastos-de-hogares/ingresos-de-los-hogares`

# %%
import preprossing

# %%
hh_char = preprossing.INECDataSet('household_characteristics').get_dataset()
hh_char
# Out:
# Start to load data...
# Processing... Please wait...
# /Users/scott/dev/ece143/preprossing.py:137: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   year_df['Category'] = year_df['Category'].apply(lambda x: self.category_translation[x])
# /Users/scott/dev/ece143/preprossing.py:138: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   year_df['year'] = year
#                                          Category     Total Quintil 1  \
# 14                                   Total people   4551553   1052105
# ...
