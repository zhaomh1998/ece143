# %%
import preprocessing
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
hh_char = preprocessing.INECDataSet('household_characteristics').get_dataset()
# Out:
# Start to load data...
# Processing... Please wait...
# /Users/scott/dev/ece143/preprocessing.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   year_df['Category'] = year_df['Category'].apply(lambda x: self.category_translation[x])
# /Users/scott/dev/ece143/preprocessing.py:145: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   year_df['year'] = year

# %%
grp = hh_char.groupby('Category')
grp.count()
# Out:
#                                              Total  Quintil 1  Quintil 2  \
# Category
# Average household income per capita             14         14         14
# Average income per household                     7          7          7
# Average schooling people of years and older     56         56         56
# Average total household income                  14         14         14
# Average weekly hours in the main job            14         14         14
# Demographic dependency relationship             56         56         56
# Economic dependency ratio                       56         56         56
# Income per household                            35         35         35
# Members per household                           56         56         56
# Net participation rate                          56         56         56
# Occupancy rate                                  21         21         21
# Occupied by household                           56         56         56
# Open unemployment rate                          56         56         56
# Per capita income per household                 42         42         42
# Percentage distribution of household income     56         56         56
# Percentage of households headed by women        56         56         56
# Total households                                56         56         56
# Total people                                    56         56         56
# Weekly hours worked in the main occupation      42         42         42
# Work force by household                         56         56         56
#
#                                              Quintil 3  Quintil 4  Quintil 5  \
# Category
# Average household income per capita                 14         14         14
# Average income per household                         7          7          7
# Average schooling people of years and older         56         56         56
# Average total household income                      14         14         14
# Average weekly hours in the main job                14         14         14
# Demographic dependency relationship                 56         56         56
# Economic dependency ratio                           56         56         56
# Income per household                                35         35         35
# Members per household                               56         56         56
# Net participation rate                              56         56         56
# Occupancy rate                                      21         21         21
# Occupied by household                               56         56         56
# Open unemployment rate                              56         56         56
# Per capita income per household                     42         42         42
# Percentage distribution of household income         56         56         56
# Percentage of households headed by women            56         56         56
# Total households                                    56         56         56
# Total people                                        56         56         56
# Weekly hours worked in the main occupation          42         42         42
# Work force by household                             56         56         56
#
#                                              region  year
# Category
# Average household income per capita              14    14
# Average income per household                      7     7
# Average schooling people of years and older      56    56
# Average total household income                   14    14
# Average weekly hours in the main job             14    14
# Demographic dependency relationship              56    56
# Economic dependency ratio                        56    56
# Income per household                             35    35
# Members per household                            56    56
# Net participation rate                           56    56
# Occupancy rate                                   21    21
# Occupied by household                            56    56
# Open unemployment rate                           56    56
# Per capita income per household                  42    42
# Percentage distribution of household income      56    56
# Percentage of households headed by women         56    56
# Total households                                 56    56
# Total people                                     56    56
# Weekly hours worked in the main occupation       42    42
# Work force by household                          56    56

# %%
average_school = grp.get_group('Average schooling people of years and older')
average_school['Total'] = average_school['Total'].astype('float')
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df11 = grp.get_group('Per capita income per household')
df22 = grp.get_group('Average household income per capita')
frames = [df11, df22]
average_income_household_person = pd.concat(frames)
average_income_household_person['Total'] = average_income_household_person['Total'].astype('float')
average_income_household_person['Quintil 1'] = average_income_household_person['Quintil 1'].astype('float')
average_income_household_person['Quintil 2'] = average_income_household_person['Quintil 2'].astype('float')
average_income_household_person['Quintil 3'] = average_income_household_person['Quintil 3'].astype('float')
average_income_household_person['Quintil 4'] = average_income_household_person['Quintil 4'].astype('float')
average_income_household_person['Quintil 5'] = average_income_household_person['Quintil 5'].astype('float')

#print(average_income_household['Total'].values)
average_income_household_person.head()
# Out:
#                            Category          Total     Quintil 1  \
# 6   Per capita income per household  268591.958450  46519.167349
# 21  Per capita income per household  304369.754169  57718.644644
# 36  Per capita income per household  204877.719063  30393.328188
# 51  Per capita income per household  217952.268695  39967.462470
# 66  Per capita income per household  200264.600494  27536.991923
#
#         Quintil 2      Quintil 3      Quintil 4      Quintil 5  \
# 6    98511.764911  157082.220504  263186.869549  777276.819380
# 21  116389.423220  182531.212162  302901.299498  862791.659768
# 36   69363.324852  107332.516720  180600.359768  637562.168022
# 51   86269.426677  131793.912692  222265.184769  610938.061871
# 66   62823.426825  103295.883453  182340.050202  629894.918939
#
#               region  year
# 6   Whole Costa Rica  2010
# 21           Central  2010
# 36         Chorotega  2010
# 51  Pacífico Central  2010
# 66            Brunca  2010

# %%
df1 = grp.get_group('Income per household')
df2 = grp.get_group('Average income per household')
df3 = grp.get_group('Average total household income')
frames = [df1, df2, df3]
average_income_household = pd.concat(frames)
average_income_household['Total'] = average_income_household['Total'].astype('float')
average_income_household['Quintil 1'] = average_income_household['Quintil 1'].astype('float')
average_income_household['Quintil 2'] = average_income_household['Quintil 2'].astype('float')
average_income_household['Quintil 3'] = average_income_household['Quintil 3'].astype('float')
average_income_household['Quintil 4'] = average_income_household['Quintil 4'].astype('float')
average_income_household['Quintil 5'] = average_income_household['Quintil 5'].astype('float')
#print(average_income_household['Total'].values)
average_income_household.head()
# Out:
#                 Category          Total      Quintil 1      Quintil 2  \
# 5   Income per household  804366.147760  190804.250500  366492.412283
# 20  Income per household  909472.747660  225715.619690  449589.737816
# 35  Income per household  611592.944525  129412.623600  272200.372646
# 50  Income per household  644143.467850  155182.670089  327772.145250
# 65  Income per household  588786.481801  110126.236357  237330.489054
#
#         Quintil 3      Quintil 4     Quintil 5            region  year
# 5   579694.390180  856579.835500  2.027385e+06  Whole Costa Rica  2010
# 20  652746.019623  993172.250393  2.227573e+06           Central  2010
# 35  399253.726060  610636.646717  1.648574e+06         Chorotega  2010
# 50  433435.090752  686582.266035  1.621399e+06  Pacífico Central  2010
# 65  378679.363632  600119.607618  1.628381e+06            Brunca  2010

# %%
#sns.boxplot(x = 'year', y = 'Total' , data = average_income_household)
plt.figure(figsize = (15, 5))
ax = plt.subplot(1, 3, 1)
sns.lineplot(x="year", y="Total", hue="region" ,data = average_income_household)
plt.title('average household income')
ax = plt.subplot(1, 3, 2)
sns.lineplot(x="year", y="Total", hue="region" ,data = average_income_household_person)
plt.title('average household income per person ')
ax = plt.subplot(1, 3, 3)
sns.lineplot(x="year", y="Total", hue="region" ,data = average_school)
plt.title('Average schooling people of years')
# Out:
# Text(0.5,1,'Average schooling people of years')

# %%
avg_income_change = pd.DataFrame()
avg_income_groups = average_income_household.groupby('region')
regions = avg_income_groups.groups.keys()
for region in regions:
    region_df = avg_income_groups.get_group(region)
    region_df[['Total change'] + ['change Quintil ' + str(i) for i in range(1,6)]] = region_df[['Total'] + ['Quintil ' + str(i) for i in range(1,6)]].pct_change()
    avg_income_change = avg_income_change.append(region_df)
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
# avg_income_change
fig, axes = plt.subplots(1,2,figsize=(15,5))
sns.lineplot(x="year", y="change Quintil 1", hue="region" ,data = avg_income_change, ax=axes[0])
sns.lineplot(x="year", y="change Quintil 5", hue="region" ,data = avg_income_change, ax=axes[1])

# %%
sns.lineplot(x="year", y="change Quintil 1", hue="region" ,data = avg_income_change, ax=axes[0])

# %%
import numpy as np
regional_change = pd.DataFrame(columns=['year','change','quintil','region'])
income_change_grp = avg_income_change.groupby('region')
regions = income_change_grp.groups.keys()
for region in regions:
    region_df = income_change_grp.get_group(region)
    quintils = pd.concat([region_df['change Quintil ' + str(i)] for i in range(1,6)]).reset_index(drop=True)
    years = pd.concat([region_df['year']]*5, ignore_index=True)
    n_quintil = (np.ones(8)*np.arange(1,6)[:,None]).flatten() # Generate numpy array for quintils
    quintil_df = pd.DataFrame({'year': years, 'change': quintils, 'quintil': n_quintil, 'region': region})
    regional_change = regional_change.append(quintil_df)

# %%
cho_change = regional_change.groupby('region').get_group('Chorotega')
sns.lineplot(x='year', y='change', hue='quintil', data=cho_change)
cho_change
# Out:
#     year    change  quintil     region
# 0   2010       NaN      1.0  Chorotega
# 1   2011 -0.078728      1.0  Chorotega
# 2   2012  0.018182      1.0  Chorotega
# 3   2013  0.030831      1.0  Chorotega
# 4   2014  0.075903      1.0  Chorotega
# 5   2015  0.104989      1.0  Chorotega
# 6   2016  0.212118      1.0  Chorotega
# 7   2017 -0.001499      1.0  Chorotega
# 8   2010       NaN      2.0  Chorotega
# 9   2011  0.020517      2.0  Chorotega
# 10  2012 -0.021508      2.0  Chorotega
# 11  2013  0.082730      2.0  Chorotega
# 12  2014  0.084498      2.0  Chorotega
# 13  2015  0.163256      2.0  Chorotega
# 14  2016 -0.010298      2.0  Chorotega
# 15  2017  0.054424      2.0  Chorotega
# 16  2010       NaN      3.0  Chorotega
# 17  2011  0.106828      3.0  Chorotega
# 18  2012 -0.072206      3.0  Chorotega
# 19  2013  0.090423      3.0  Chorotega
# 20  2014  0.150456      3.0  Chorotega
# 21  2015  0.249763      3.0  Chorotega
# 22  2016  0.032694      3.0  Chorotega
# 23  2017 -0.035361      3.0  Chorotega
# 24  2010       NaN      4.0  Chorotega
# 25  2011  0.107772      4.0  Chorotega
# 26  2012  0.020800      4.0  Chorotega
# 27  2013  0.083634      4.0  Chorotega
# 28  2014  0.024766      4.0  Chorotega
# 29  2015  0.264619      4.0  Chorotega
# 30  2016 -0.032032      4.0  Chorotega
# 31  2017  0.000314      4.0  Chorotega
# 32  2010       NaN      5.0  Chorotega
# 33  2011 -0.038561      5.0  Chorotega
# 34  2012 -0.028493      5.0  Chorotega
# 35  2013  0.028529      5.0  Chorotega
# 36  2014  0.055327      5.0  Chorotega
# 37  2015  0.212138      5.0  Chorotega
# 38  2016 -0.041006      5.0  Chorotega
# 39  2017 -0.020003      5.0  Chorotega

# %%
plt.figure(figsize = (25, 20))
for i, col in enumerate(['Quintil 1','Quintil 2','Quintil 3','Quintil 4','Quintil 5']):
    ax = plt.subplot(2, 3, i + 1)
    sns.lineplot(x="year", y=col, hue="region" ,data = average_income_household)
    plt.title('%s lineplot'%(col.capitalize()))
    plt.xlabel('%s'%col)

# %%
edu = preprocessing.INECDataSet('edu_lvl').get_dataset()
# Out:
# Start to load data...

# %%
edu
# Out:
#                region  total no education incomplete primary complete primary  \
# 0               Total      1       342783             804670           974005
# 1               Total      0       173173             389207           479611
# 2               Total      0       169610             415463           494394
# 3              Urbana      1       208386             499808           638536
# 4              Urbana      0       104399             228286           307287
# 5              Urbana      0       103987             271522           331249
# 6               Rural      1       134397             304862           335469
# 7               Rural      0        68774             160921           172324
# 8               Rural      0        65623             143941           163145
# 9             Central      1       177536             425073           592660
# 10            Central      0        89690             196794           286392
# 11            Central      0        87846             228279           306268
# 12          Chorotega      1        29911              72042            77467
# 13          Chorotega      0        14629              37272            39848
# 14          Chorotega      0        15282              34770            37619
# 15   Pacífico Central      1        22090              51045            51159
# 16   Pacífico Central      0        10944              26330            25889
# 17   Pacífico Central      0        11146              24715            25270
# 18             Brunca      1        30586              79144            88595
# 19             Brunca      0        15454              40711            45598
# 20             Brunca      0        15132              38433            42997
# 21   Huetar Atlántica      1        40106              95355            89291
# 22   Huetar Atlántica      0        20965              46616            44099
# 23   Huetar Atlántica      0        19141              48739            45192
# 24       Huetar Norte      1        42554              82011            74833
# 25       Huetar Norte      0        21491              41484            37785
# 26       Huetar Norte      0        21063              40527            37048
# 27              Total      1       319611             810975           992538
# 28              Total      0       167125             398046           491001
# 29              Total      0       152486             412929           501537
# ..                ...    ...          ...                ...              ...
# 186      Huetar Norte      1        47879              91171            85609
# 187      Huetar Norte      0        24927              49165            42463
# 188      Huetar Norte      0        22952              42006            43146
# 189             Total      1       333412             836796          1022936
# 190             Total      0       168352             408999           517886
# 191             Total      0       165060             427797           505050
# 192            Urbana      1       206654             532897           678495
# 193            Urbana      0        98968             255212           332516
# 194            Urbana      0       107686             277685           345979
# 195             Rural      1       126758             303899           344441
# 196             Rural      0        69384             153787           185370
# 197             Rural      0        57374             150112           159071
# 198           Central      1       167764             438676           625016
# 199           Central      0        84149             207704           311164
# 200           Central      0        83615             230972           313852
# 201         Chorotega      1        27269              68860            70894
# 202         Chorotega      0        12762              33903            37132
# 203         Chorotega      0        14507              34957            33762
# 204  Pacífico Central      1        22391              60378            62066
# 205  Pacífico Central      0        12007              31166            32729
# 206  Pacífico Central      0        10384              29212            29337
# 207            Brunca      1        30122              77266            79622
# 208            Brunca      0        15330              36709            39953
# 209            Brunca      0        14792              40557            39669
# 210     Huetar Caribe      1        38047              95237           100640
# 211     Huetar Caribe      0        18276              50471            52336
# 212     Huetar Caribe      0        19771              44766            48304
# 213      Huetar Norte      1        47819              96379            84698
# 214      Huetar Norte      0        25828              49046            44572
# 215      Huetar Norte      0        21991              47333            40126
#
#     secondary incomplete secondary complete technical secondary incomplete  \
# 0                 823792             474721                          44302
# 1                 402412             222741                          20352
# 2                 421380             251980                          23950
# 3                 645985             401822                          27356
# 4                 314591             186679                          12844
# 5                 331394             215143                          14512
# 6                 177807              72899                          16946
# 7                  87821              36062                           7508
# 8                  89986              36837                           9438
# 9                 533829             341530                          18763
# 10                262456             159962                           7949
# 11                271373             181568                          10814
# 198                        45301        569131        59131        1183  2017
# 199                        21660        258396        29818         835  2017
# 200                        23641        310735        29313         348  2017
# 201                         6649         47374         3921           0  2017
# 202                         3021         17293         1999           0  2017
# 203                         3628         30081         1922           0  2017
# 204                         4820         25657         2816         235  2017
# 205                         2641         11432         1422           0  2017
# 206                         2179         14225         1394         235  2017
# 207                         4734         36104         2287         124  2017
# 208                         2324         15150          580         124  2017
# 209                         2410         20954         1707           0  2017
# 210                         6034         31706         2712           0  2017
# 211                         3122         13573          856           0  2017
# 212                         2912         18133         1856           0  2017
# 213                         3670         24868         1658           0  2017
# 214                         2160          8441          735           0  2017
# 215                         1510         16427          923           0  2017
#
#      male
# 0       0
# 1       1
# 2       0
# 3       0
# 4       1
# 5       0
# 6       0
# 7       1
# 8       0
# 9       0
# 10      1
# 11      0
# 12      0
# 13      1
# 14      0
# 15      0
# 16      1
# 17      0
# 18      0
# 19      1
# 20      0
# 21      0
# 22      1
# 23      0
# 24      0
# 25      1
# 26      0
# 27      0
# 28      1
# 29      0
# ..    ...
# 186     0
# 187     1
# 188     0
# 189     0
# 190     1
# 191     0
# 192     0
# 193     1
# 194     0
# 195     0
# 196     1
# 197     0
# 198     0
# 199     1
# 200     0
# 201     0
# 202     1
# 203     0
# 204     0
# 205     1
# 206     0
# 207     0
# 208     1
# 209     0
# 210     0
# 211     1
# 212     0
# 213     0
# 214     1
# 215     0
#
# [216 rows x 14 columns]

# %%
region = edu.pop('region')
edu = edu.astype('float64')
edu.insert(0,'region',region)
# Out:
#                region  total  no education  incomplete primary  \
# 0               Total    1.0      342783.0            804670.0
# 1               Total    0.0      173173.0            389207.0
# 2               Total    0.0      169610.0            415463.0
# 3              Urbana    1.0      208386.0            499808.0
# 4              Urbana    0.0      104399.0            228286.0
# 5              Urbana    0.0      103987.0            271522.0
# 6               Rural    1.0      134397.0            304862.0
# 7               Rural    0.0       68774.0            160921.0
# 8               Rural    0.0       65623.0            143941.0
# 9             Central    1.0      177536.0            425073.0
# 10            Central    0.0       89690.0            196794.0
# 11            Central    0.0       87846.0            228279.0
# 12          Chorotega    1.0       29911.0             72042.0
# 13          Chorotega    0.0       14629.0             37272.0
# 14          Chorotega    0.0       15282.0             34770.0
# 15   Pacífico Central    1.0       22090.0             51045.0
# 16   Pacífico Central    0.0       10944.0             26330.0
# 17   Pacífico Central    0.0       11146.0             24715.0
# 18             Brunca    1.0       30586.0             79144.0
# 19             Brunca    0.0       15454.0             40711.0
# 20             Brunca    0.0       15132.0             38433.0
# 21   Huetar Atlántica    1.0       40106.0             95355.0
# 22   Huetar Atlántica    0.0       20965.0             46616.0
# 23   Huetar Atlántica    0.0       19141.0             48739.0
# 24       Huetar Norte    1.0       42554.0             82011.0
# 25       Huetar Norte    0.0       21491.0             41484.0
# 26       Huetar Norte    0.0       21063.0             40527.0
# 27              Total    1.0      319611.0            810975.0
# 28              Total    0.0      167125.0            398046.0
# 29              Total    0.0      152486.0            412929.0
# ..                ...    ...           ...                 ...
# 186      Huetar Norte    1.0       47879.0             91171.0
# 187      Huetar Norte    0.0       24927.0             49165.0
# 188      Huetar Norte    0.0       22952.0             42006.0
# 29        360798.0       31620.0       2866.0  2011.0   0.0
# ..             ...           ...          ...     ...   ...
# 186        23009.0        1714.0        251.0  2016.0   0.0
# 187         8865.0         730.0        251.0  2016.0   1.0
# 188        14144.0         984.0          0.0  2016.0   0.0
# 189       734840.0       72525.0       1542.0  2017.0   0.0
# 190       324285.0       35410.0        959.0  2017.0   1.0
# 191       410555.0       37115.0        583.0  2017.0   0.0
# 192       634585.0       64736.0       1542.0  2017.0   0.0
# 193       284549.0       31666.0        959.0  2017.0   1.0
# 194       350036.0       33070.0        583.0  2017.0   0.0
# 195       100255.0        7789.0          0.0  2017.0   0.0
# 196        39736.0        3744.0          0.0  2017.0   1.0
# 197        60519.0        4045.0          0.0  2017.0   0.0
# 198       569131.0       59131.0       1183.0  2017.0   0.0
# 199       258396.0       29818.0        835.0  2017.0   1.0
# 200       310735.0       29313.0        348.0  2017.0   0.0
# 201        47374.0        3921.0          0.0  2017.0   0.0
# 202        17293.0        1999.0          0.0  2017.0   1.0
# 203        30081.0        1922.0          0.0  2017.0   0.0
# 204        25657.0        2816.0        235.0  2017.0   0.0
# 205        11432.0        1422.0          0.0  2017.0   1.0
# 206        14225.0        1394.0        235.0  2017.0   0.0
# 207        36104.0        2287.0        124.0  2017.0   0.0
# 208        15150.0         580.0        124.0  2017.0   1.0
# 209        20954.0        1707.0          0.0  2017.0   0.0
# 210        31706.0        2712.0          0.0  2017.0   0.0
# 211        13573.0         856.0          0.0  2017.0   1.0
# 212        18133.0        1856.0          0.0  2017.0   0.0
# 213        24868.0        1658.0          0.0  2017.0   0.0
# 214         8441.0         735.0          0.0  2017.0   1.0
# 215        16427.0         923.0          0.0  2017.0   0.0
#
# [216 rows x 15 columns]

# %%
total = edu[edu['total']==1]
df1 = total[total['region'] == 'Urbana']
df2 = total[total['region'] == 'Rural']
frames = [df1, df2]
total_zone = pd.concat(frames)

# %%
sns.lineplot(x="year", y="undergraduate", hue="region" ,data = total_zone)

# %%
aa = edu.groupby('region')
aa.count()
# Out:
#                   total  no education  incomplete primary  complete primary  \
# region
# Brunca               24            24                  24                24
# Central              24            24                  24                24
# Chorotega            24            24                  24                24
# Huetar Atlántica      9             9                   9                 9
# Huetar Caribe        15            15                  15                15
# Huetar Norte         24            24                  24                24
# Pacífico Central     24            24                  24                24
# Rural                24            24                  24                24
# Total                24            24                  24                24
# Urbana               24            24                  24                24
#
#                   secondary incomplete  secondary complete  \
# region
# Brunca                              24                  24
# Central                             24                  24
# Chorotega                           24                  24
# Huetar Atlántica                     9                   9
# Huetar Caribe                       15                  15
# Huetar Norte                        24                  24
# Pacífico Central                    24                  24
# Rural                               24                  24
# Total                               24                  24
# Urbana                              24                  24
#
#                   technical secondary incomplete  \
# region
# Brunca                                        24
# Central                                       24
# Chorotega                                     24
# Huetar Atlántica                               9
# Huetar Caribe                                 15
# Huetar Norte                                  24
# Pacífico Central                              24
# Rural                                         24
# Total                                         24
# Urbana                                        24
#
#                   technical secondary complete  undergraduate  postgraduate  \
# region
# Brunca                                      24             24            24
# Central                                     24             24            24
# Chorotega                                   24             24            24
# Huetar Atlántica                             9              9             9
# Huetar Caribe                               15             15            15
# Huetar Norte                                24             24            24
# Pacífico Central                            24             24            24
# Rural                                       24             24            24
# Total                                       24             24            24
# Urbana                                      24             24            24
#
#                   no response  year  male
# region
# Brunca                     24    24    24
# Central                    24    24    24
# Chorotega                  24    24    24
# Huetar Atlántica            9     9     9
# Huetar Caribe              15    15    15
# Huetar Norte               24    24    24
# Pacífico Central           24    24    24
# Rural                      24    24    24
# Total                      24    24    24
# Urbana                     24    24    24

# %%
total_region = total[total.region.isin(['Brunca','Central','Chorotega','Huetar Atlántica','Huetar Caribe','Huetar Norte','Pacífico Central'])]
total_region.groupby('region').count()
sns.lineplot(x="year", y="undergraduate", hue="region" ,data = total_region)

# %%
aa = total[total.region.isin(['Brunca','Central','Chorotega','Huetar Atlántica','Huetar Caribe','Huetar Norte','Pacífico Central'])]
qq = aa[['population','no education','complete primary','secondary complete','technical secondary complete','undergraduate','postgraduate']]
qq = qq.divide(qq['population'],axis=0)
qq.insert(0,'region',aa['region'])
qq.insert(0,'year',aa['year'])
plt.figure(figsize = (25, 15))
for i, col in enumerate(['no education','complete primary','secondary complete','technical secondary complete','undergraduate','postgraduate']):
    ax = plt.subplot(2, 3, i+1)
    sns.lineplot(x="year", y=col, hue="region" ,data = qq)
    plt.title('%s lineplot'%(col.capitalize()))
    plt.xlabel('%s'%col)

# %%
qq = aa[['population','no education','complete primary','secondary complete','technical secondary complete','undergraduate','postgraduate']]
qq = qq.divide(qq['population'],axis=0)
qq.head()
# Out:
#     population  no education  complete primary  secondary complete  \
# 9          1.0      0.105908          0.353548            0.203738
# 12         1.0      0.168475          0.436335            0.172547
# 15         1.0      0.171258          0.396621            0.204129
# 18         1.0      0.165548          0.479524            0.137322
# 21         1.0      0.208975          0.465256            0.143869
#
#     technical secondary complete  undergraduate  postgraduate
# 9                       0.023554       0.281929      0.031324
# 12                      0.020046       0.189231      0.013366
# 15                      0.032143       0.173940      0.021909
# 18                      0.026381       0.171756      0.019469
# 21                      0.029513       0.131718      0.020670

# %%
aa['region']
# Out:
# 9               Central
# 12            Chorotega
# 15     Pacífico Central
# 18               Brunca
# 21     Huetar Atlántica
# 24         Huetar Norte
# 36              Central
# 39            Chorotega
# 42     Pacífico Central
# 45               Brunca
# 48     Huetar Atlántica
# 51         Huetar Norte
# 63              Central
# 66            Chorotega
# 69     Pacífico Central
# 72               Brunca
# 75     Huetar Atlántica
# 78         Huetar Norte
# 90              Central
# 93            Chorotega
# 96     Pacífico Central
# 99               Brunca
# 102       Huetar Caribe
# 105        Huetar Norte
# 117             Central
# 120           Chorotega
# 123    Pacífico Central
# 126              Brunca
# 129       Huetar Caribe
# 132        Huetar Norte
# 144             Central
# 147           Chorotega
# 150    Pacífico Central
# 153              Brunca
# 156       Huetar Caribe
# 159        Huetar Norte
# 171             Central
# 174           Chorotega
# 177    Pacífico Central
# 180              Brunca
# 183       Huetar Caribe
# 186        Huetar Norte
# 198             Central
# 201           Chorotega
# 204    Pacífico Central
# 207              Brunca
# 210       Huetar Caribe
# 213        Huetar Norte
# Name: region, dtype: object
