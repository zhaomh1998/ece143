# %% [markdown]
# # Load datasets from INEC
# household_characteristics: `http://www.inec.go.cr/ingresos-y-gastos-de-hogares/ingresos-de-los-hogares`
#
# Education: `http://www.inec.go.cr/educacion`

# %%
import preprocessing

# %%
household_characteriscits = preprocessing.INECDataSet('household_characteristics')
print(household_characteriscits.get_dataset_description())
hh_char = household_characteriscits.get_dataset()
hh_char
# Out:
# Start to load data...
# Processing... Please wait...
# /Users/scott/dev/ece143/preprocessing.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   year_df['Category'] = year_df['Category'].apply(lambda x: self.category_translation[x])
# /Users/scott/dev/ece143/preprocessing.py:145: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   year_df['year'] = year
# Main characteristics of households and people
# By quintiles of household income per capita
# According to planning region
# July 2010-2017
# (Excludes domestic service and pensioners)
#                                         Category     Total Quintil 1  \
# 0                                   Total people   4551553   1052105
# 1                               Total households   1289716    257879
# 2                          Members per household   3.52911   4.07984
# 3                        Work force by household   1.58406   1.17657
# 4                          Occupied by household   1.46817  0.935943
# 5                           Income per household    804366    190804
# 6                Per capita income per household    268592   46519.2
# 7       Percentage of households headed by women   33.6888   34.0799
# 8    Percentage distribution of household income       100   4.74303
# 9            Demographic dependency relationship  0.464744  0.729458
# 10                     Economic dependency ratio   1.22789   2.46758
# 11    Weekly hours worked in the main occupation   44.9244   39.2666
# 12   Average schooling people of years and older   8.37929   6.00487
# 13                        Open unemployment rate   7.31596   20.4514
# 14                        Net participation rate   59.0129    44.598
# 15                                  Total people   2983566    664513
# 16                              Total households    851080    170600
# 17                         Members per household   3.50562   3.89515
# 18                       Work force by household   1.67455   1.26335
# 19                         Occupied by household   1.55794   1.00565
# 20                          Income per household    909473    225716
# 21               Per capita income per household    304370   57718.6
# 22      Percentage of households headed by women   35.3642   36.1782
# 23   Percentage distribution of household income       100   4.97486
# 24           Demographic dependency relationship  0.429522   0.66936
# 25                     Economic dependency ratio   1.09348   2.08319
# 26    Weekly hours worked in the main occupation   44.8927   41.3191
# 27   Average schooling people of years and older   8.96571   6.51996
# 28                        Open unemployment rate   6.96323   20.3983
# 29                        Net participation rate   60.9798   47.9305
# ..                                           ...       ...       ...
# 831                        Members per household   3.28587   3.78172
# 832                      Work force by household   1.31969  0.921298
# 833                        Occupied by household    1.1987  0.679858
# 834               Average total household income    693042    175238
# 835          Average household income per capita    245882   46398.6
# 836     Percentage of households headed by women   37.5929   50.9263
# 837  Percentage distribution of household income       100   5.05258
# 838          Demographic dependency relationship  0.523634  0.856904
# 839                    Economic dependency ratio   1.48987   3.10477
# 840         Average weekly hours in the main job   44.0962   30.7586
# 841  Average schooling people of years and older   7.61325     6.046
# 842                       Open unemployment rate   9.16808   26.2066
# 843                       Net participation rate   55.6021   40.2369
# 844                               Occupancy rate   50.5044   29.6922
# 845                                 Total people    399295     86002
# 846                             Total households    119165     24016
# 847                        Members per household   3.35077   3.58103
# 848                      Work force by household   1.35779  0.877249
# 849                        Occupied by household   1.24285  0.627373
# 850               Average total household income    748026    157213
# 851          Average household income per capita    253946   42437.4
# 852     Percentage of households headed by women   30.2043   36.3466
# 853  Percentage distribution of household income       100   4.23568
# 854          Demographic dependency relationship  0.530018  0.872377
# 855                    Economic dependency ratio   1.46782   3.08212
# 856         Average weekly hours in the main job   43.7611   30.9786
# 857  Average schooling people of years and older   7.01361   5.23824
# 858                       Open unemployment rate   8.46534    28.484
# 859                       Net participation rate   55.2114    38.681
# 860                               Occupancy rate   50.5376   27.6631
# 850    359722    536029    843335  1.84854e+06      Huetar Norte  2017
# 851   96640.2    155119    253420       723717      Huetar Norte  2017
# 852   33.0993   29.5541    28.885      23.0824      Huetar Norte  2017
# 853   9.60013   14.2939   22.5019      49.3683      Huetar Norte  2017
# 854  0.661654  0.568219  0.344881     0.258518      Huetar Norte  2017
# 855    1.9777   1.54902   1.04767     0.587955      Huetar Norte  2017
# 856   41.4031   44.2499   47.9374       45.775      Huetar Norte  2017
# 857   6.00375    6.4227   7.81208      9.64521      Huetar Norte  2017
# 858   13.7223   7.73936   2.64506     0.312927      Huetar Norte  2017
# 859   48.3016   53.9216   61.8109      73.1333      Huetar Norte  2017
# 860   41.6735   49.7484    60.176      72.9044      Huetar Norte  2017
#
# [861 rows x 9 columns]

# %%
education = preprocessing.INECDataSet('edu')
print(education.get_dataset_description())
edu = education.get_dataset()
edu.head()
# Out:
# Start to load data...
# Costa Rica: Population from 5 to 24 years old, percentage distribution
#
# For attendance at regular education
# According to planning area and region
# /Users/scott/dev/ece143/preprocessing.py:183: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.df['region'][self.df['region'] == 'Huetar Caribe'] = 'Huetar Atlántica'  # Correct old region name
#       region 5-24 total 5-24 not attend% 5-24 attend% 5-12 total  \
# 0      Total    1646747          29.6364      70.3636     581477
# 1     Urbana    1158249          28.9644      71.0356     389829
# 2      Rural     488498          31.2296      68.7704     191648
# 3    Central     983942          29.5238      70.4762     328945
# 4  Chorotega     131340          30.0122      69.9878      47884
#
#   5-12 not attend% 5-12 attend% 13-17 total 13-17 not attend% 13-17 attend%  \
# 0          3.86223      96.1378      436865            16.864        83.136
# 1          3.00568      96.9943      297708           14.0668       85.9332
# 2          5.60455      94.3955      139157           22.8483       77.1517
# 3           2.8184      97.1816      249967           14.4067       85.5933
# 4          4.88472      95.1153       36693           18.5076       81.4924
#
#   18-24 total 18-24 not attend% 18-24 attend%  year
# 0      628405            62.365        37.635  2010
# 1      470712           59.8848       40.1152  2010
# 2      157693           69.7685       30.2315  2010
# 3      405030           60.5422       39.4578  2010
# 4       46763           64.7692       35.2308  2010

# %%
edu.groupby('region').count()
# Out:
#                   5-24 total  5-24 not attend%  5-24 attend%  5-12 total  \
# region
# Brunca                     8                 8             8           8
# Central                    8                 8             8           8
# Chorotega                  8                 8             8           8
# Huetar Atlántica           8                 8             8           8
# Huetar Norte               8                 8             8           8
# Pacífico Central           8                 8             8           8
# Rural                      8                 8             8           8
# Total                      8                 8             8           8
# Urbana                     8                 8             8           8
#
#                   5-12 not attend%  5-12 attend%  13-17 total  \
# region
# Brunca                           8             8            8
# Central                          8             8            8
# Chorotega                        8             8            8
# Huetar Atlántica                 8             8            8
# Huetar Norte                     8             8            8
# Pacífico Central                 8             8            8
# Rural                            8             8            8
# Total                            8             8            8
# Urbana                           8             8            8
#
#                   13-17 not attend%  13-17 attend%  18-24 total  \
# region
# Brunca                            8              8            8
# Central                           8              8            8
# Chorotega                         8              8            8
# Huetar Atlántica                  8              8            8
# Huetar Norte                      8              8            8
# Pacífico Central                  8              8            8
# Rural                             8              8            8
# Total                             8              8            8
# Urbana                            8              8            8
#
#                   18-24 not attend%  18-24 attend%  year
# region
# Brunca                            8              8     8
# Central                           8              8     8
# Chorotega                         8              8     8
# Huetar Atlántica                  8              8     8
# Huetar Norte                      8              8     8
# Pacífico Central                  8              8     8
# Rural                             8              8     8
# Total                             8              8     8
# Urbana                            8              8     8
